# %% [markdown]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/gulshanhatzade/GScream.git

# %%
mv /kaggle/input/code-a03/GScream /kaggle/working/
# Out:
# mv: cannot remove '/kaggle/input/code-a03/GScream/train.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/colmap_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/system_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/graphics_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/camera_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/loss_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/visualize_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/my_ssim.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/general_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/sh_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/utils/image_utils.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/9_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/12_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/4_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/4_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/book_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/9_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/12_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/7_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/1_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/10_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/10_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/2_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/3_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/2_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/trash_out.png': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/7_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/book_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/1_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/trash_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/refs/3_out_pred.npy': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/scripts/run.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/rasterize_points.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/LICENSE.md': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/.gitignore': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/.gitmodules': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/ext.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/stbi_image_write.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/cmake/cmake_uninstall.cmake.in': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/.travis.yml': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/.gitignore': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/copying.txt': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/readme.md': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/manual.md': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/glm.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat2x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/vector_relational.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/geometric.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/matrix.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/vec2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/vec4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/packing.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/vec3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat2x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat3x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat2x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat4x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat3x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/trigonometric.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/fwd.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/packing.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/geometric.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/integer.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/trigonometric.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/vector_relational.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/matrix.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/common.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/neon.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/exponential.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/simd/platform.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/exponential.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat4x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/fast_square_root.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/orthonormalize.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/vec_swizzle.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_interpolation.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/wrap.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/string_cast.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/fast_trigonometry.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_factorisation.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_cross_product.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/color_space_YCoCg.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/norm.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/string_cast.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/gradient_paint.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/color_space.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/transform2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/handed_coordinate_space.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/mixed_product.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/polar_coordinates.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/type_trait.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/transform2.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/component_wise.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/functions.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/euler_angles.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/associated_min_max.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_decompose.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/color_encoding.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/optimum_pow.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/gradient_paint.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/std_based_type.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/closest_point.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/projection.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/range.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/extended_min_max.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/color_space_YCoCg.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_operation.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/std_based_type.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/optimum_pow.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/common.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/dual_quaternion.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_factorisation.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/normal.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_major_storage.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/vector_query.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/norm.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/intersect.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/color_space.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/easing.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/type_trait.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/scalar_relational.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/integer.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/spline.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/extend.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/texture.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_major_storage.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/quaternion.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/perpendicular.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/float_notmalize.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/raw_data.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/compatibility.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/exterior_product.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/exterior_product.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/projection.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_transform_2d.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_operation.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/normalize_dot.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/rotate_normalized_axis.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/vector_query.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/number_precision.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/mixed_product.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/rotate_vector.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/perpendicular.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/type_aligned.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/io.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/type_aligned.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/closest_point.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/raw_data.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/fast_exponential.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/bit.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/scalar_multiplication.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_interpolation.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/common.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/quaternion.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/normal.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/integer.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/polar_coordinates.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/rotate_normalized_axis.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/associated_min_max.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_transform_2d.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/pca.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_cross_product.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/hash.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/euler_angles.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/extended_min_max.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/bit.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/compatibility.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_query.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/transform.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/component_wise.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/normalize_dot.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/color_encoding.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/hash.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/fast_exponential.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/fast_trigonometry.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/extend.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/functions.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_decompose.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/handed_coordinate_space.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/dual_quaternion.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/fast_square_root.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/number_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/vector_angle.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/io.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/texture.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/pca.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/rotate_vector.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/wrap.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/matrix_query.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/vector_angle.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/scalar_relational.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/orthonormalize.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/transform.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/easing.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/intersect.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtx/spline.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/common.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat3x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/integer.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/bitfield.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/matrix_integer.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/epsilon.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/round.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/random.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/type_ptr.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/ulp.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/matrix_inverse.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/color_space.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/packing.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/color_space.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/integer.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/reciprocal.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/ulp.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/noise.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/type_precision.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/quaternion.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/round.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/type_aligned.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/bitfield.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/matrix_inverse.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/noise.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/random.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/type_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/quaternion.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/integer.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/matrix_transform.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/epsilon.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/matrix_access.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/matrix_access.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/packing.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/type_ptr.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/vec1.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/constants.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/constants.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/matrix_transform.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/gtc/quaternion_simd.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/mat4x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float2x2_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_uint4_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_float4_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_integer.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint4x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_ulp.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_geometric.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int2x3_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_relational.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int3x2_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double3x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float2x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_trigonometric.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float4x3_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double3x4_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_bool3_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_common.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_double_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_bool1.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_float2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint3x2_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_clip_space.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint2x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_float.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int3x3_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float2x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint4x2_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_double1_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int4x2_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_common.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_integer.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_float2_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_float1.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double4x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_clip_space.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float2x4_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_integer.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_packing.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_reciprocal.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint2x2_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/scalar_packing.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_uint2_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double2x3_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint4x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float2x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float3x4_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint3x3_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_double1.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/scalar_uint_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float4x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_common.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint2x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint2x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_exponential.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int3x4_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/scalar_ulp.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_int4_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int3x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint4x3_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_uint4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double4x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int4x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int2x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_int2_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_uint2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_common.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double4x2_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double2x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float4x3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/scalar_relational.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/scalar_reciprocal.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_packing.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_int3_sized.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float3x2.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double2x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_uint3x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float2x3_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_float1_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_transform.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_float3x4.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/vector_bool3.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/quaternion_relational.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/scalar_ulp.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_double2x4_precision.hpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/scalar_common.inl': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/glm/ext/matrix_int4x4_sized.hpp': Read-only file system
# ...
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_uint2x2_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_uint4x3_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_int2x2_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vector_int4_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vector_packing.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vector_relational.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_uint4x4_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_quaternion_trigonometric.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vector_bool1.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vector_ulp.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vec1.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/CMakeLists.txt': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_quaternion_transform.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_scalar_ulp.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_quaternion_common.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vector_uint4_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_int3x4_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_uint3x4_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_scalar_integer.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_quaternion_relational.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_int3x2_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_matrix_relational.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/ext/ext_vector_uint2_sized.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/third_party/glm/test/CMakeLists.txt': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/diff_gaussian_rasterization/_C.cpython-37m-x86_64-linux-gnu.so': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/diff_gaussian_rasterization/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/rasterize_points.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/CMakeLists.txt': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/config.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/rasterizer_impl.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/forward.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/rasterizer.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/backward.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/backward.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/rasterizer_impl.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/forward_reweighted.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/backward_reweighted.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/cuda_rasterizer/forward.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/diff-gaussian-rasterization/setup.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn/_C.cpython-37m-x86_64-linux-gnu.so': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn/.gitkeep': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/ext.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/spatial.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/spatial.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/build/temp.linux-x86_64-cpython-37/build.ninja': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/build/temp.linux-x86_64-cpython-37/.ninja_log': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/build/temp.linux-x86_64-cpython-37/ext.o': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/build/temp.linux-x86_64-cpython-37/simple_knn.o': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/build/temp.linux-x86_64-cpython-37/.ninja_deps': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/build/temp.linux-x86_64-cpython-37/spatial.o': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/build/lib.linux-x86_64-cpython-37/simple_knn/_C.cpython-37m-x86_64-linux-gnu.so': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn.egg-info/dependency_links.txt': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn.egg-info/SOURCES.txt': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn.egg-info/top_level.txt': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/simple_knn.egg-info/PKG-INFO': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/submodules/simple-knn/setup.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/gaussian_renderer/network_gui.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/gaussian_renderer/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/arguments/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/log_training/.placeholder': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/persistence.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/training_stats.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/misc.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/conv2d_resample.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/filtered_lrelu.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/upfirdn2d.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/fma.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/bias_act.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/filtered_lrelu_rd.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/bias_act.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/bias_act.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/upfirdn2d.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/bias_act.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/filtered_lrelu.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/conv2d_gradfix.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/grid_sample_gradfix.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/upfirdn2d.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/upfirdn2d.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/filtered_lrelu.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/filtered_lrelu_wr.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/filtered_lrelu_ns.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/ops/filtered_lrelu.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/custom_ops.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/torch_utils/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/scene/cameras.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/scene/dataset_readers.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/scene/gaussian_model.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/scene/colmap_loader.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/scene/stylegan2.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/scene/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/gscream.yaml': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/data/.placeholder': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/generator_loss.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/persistence.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/training_stats.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/misc.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/conv2d_resample.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/filtered_lrelu.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/upfirdn2d.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/fma.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/bias_act.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/filtered_lrelu_rd.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/bias_act.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/bias_act.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/upfirdn2d.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/bias_act.h': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/filtered_lrelu.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/conv2d_gradfix.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/grid_sample_gradfix.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/upfirdn2d.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/upfirdn2d.cpp': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/filtered_lrelu.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/filtered_lrelu_wr.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/filtered_lrelu_ns.cu': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/ops/filtered_lrelu.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/custom_ops.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/torch_utils/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/dnnlib/__init__.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/dnnlib/util.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/generator.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/stylegan2.py': Read-only file system
# mv: cannot remove '/kaggle/input/code-a03/GScream/generator/paired_image_dataset.py': Read-only file system

# %%
# %cd GScream
# Out:
# /kaggle/working/GScream

# %%
# !pip install appdirs==1.4.4 bidirectional-cross-attention==0.0.4 click==8.1.7 colorama==0.4.6 cycler==0.11.0 docker-pycreds==0.4.0 einops==0.6.1 fonttools==4.38.0 gitdb==4.0.11 gitpython==3.1.41 importlib-metadata==6.7.0 jaxtyping==0.2.12 joblib==1.3.2 kornia==0.6.12 lpips==0.1.4 matplotlib==3.5.3 opencv-python==4.9.0.80 packaging==23.2 plyfile==0.8.1 prettytable==3.7.0 protobuf==4.24.4 psutil==5.9.7 pyparsing==3.1.1 python-dateutil==2.8.2 pytorch-fid==0.3.0 pyyaml==6.0.1 scikit-learn==1.0.2 scipy==1.7.3 sentry-sdk==1.39.2 setproctitle==1.3.3 six==1.16.0 smmap==5.0.1 threadpoolctl==3.1.0 torch-scatter==2.1.1 tqdm==4.66.1 typeguard==4.1.2 wandb==0.16.2 wcwidth==0.2.13 zipp==3.15.0
# Out:
# Collecting appdirs==1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting bidirectional-cross-attention==0.0.4
#   Downloading bidirectional_cross_attention-0.0.4-py3-none-any.whl.metadata (685 bytes)
# Requirement already satisfied: click==8.1.7 in /usr/local/lib/python3.10/dist-packages (8.1.7)
# Requirement already satisfied: colorama==0.4.6 in /usr/local/lib/python3.10/dist-packages (0.4.6)
# Collecting cycler==0.11.0
#   Downloading cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# Requirement already satisfied: docker-pycreds==0.4.0 in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Collecting einops==0.6.1
#   Downloading einops-0.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting fonttools==4.38.0
#   Downloading fonttools-4.38.0-py3-none-any.whl.metadata (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: gitdb==4.0.11 in /usr/local/lib/python3.10/dist-packages (4.0.11)
# Collecting gitpython==3.1.41
#   Downloading GitPython-3.1.41-py3-none-any.whl.metadata (14 kB)
# Collecting importlib-metadata==6.7.0
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting jaxtyping==0.2.12
#   Downloading jaxtyping-0.2.12-py3-none-any.whl.metadata (2.8 kB)
# Collecting joblib==1.3.2
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting kornia==0.6.12
#   Downloading kornia-0.6.12-py2.py3-none-any.whl.metadata (12 kB)
# Collecting lpips==0.1.4
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Collecting matplotlib==3.5.3
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting opencv-python==4.9.0.80
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting packaging==23.2
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting plyfile==0.8.1
#   Downloading plyfile-0.8.1-py3-none-any.whl.metadata (21 kB)
# Collecting prettytable==3.7.0
#   Downloading prettytable-3.7.0-py3-none-any.whl.metadata (26 kB)
# Collecting protobuf==4.24.4
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Collecting psutil==5.9.7
#   Downloading psutil-5.9.7-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting pyparsing==3.1.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil==2.8.2
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting pytorch-fid==0.3.0
#   Downloading pytorch_fid-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyyaml==6.0.1
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting scikit-learn==1.0.2
#   Downloading scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting scipy==1.7.3
#   Downloading scipy-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting sentry-sdk==1.39.2
#   Downloading sentry_sdk-1.39.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle==1.3.3
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: smmap==5.0.1 in /usr/local/lib/python3.10/dist-packages (5.0.1)
# Collecting threadpoolctl==3.1.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting torch-scatter==2.1.1
#   Downloading torch_scatter-2.1.1.tar.gz (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.6/107.6 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tqdm==4.66.1
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.1 MB/s eta 0:00:00
# Collecting typeguard==4.1.2
#   Downloading typeguard-4.1.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting wandb==0.16.2
#   Downloading wandb-0.16.2-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /usr/local/lib/python3.10/dist-packages (0.2.13)
# Collecting zipp==3.15.0
#   Downloading zipp-3.15.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.10/dist-packages (from bidirectional-cross-attention==0.0.4) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from jaxtyping==0.2.12) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from jaxtyping==0.2.12) (4.12.2)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (0.20.1+cu121)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.5.3) (11.0.0)
# Collecting numpy>=1.20.0 (from jaxtyping==0.2.12)
#   Downloading numpy-1.22.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from sentry-sdk==1.39.2) (2025.1.31)
# Requirement already satisfied: urllib3>=1.26.11 in /usr/local/lib/python3.10/dist-packages (from sentry-sdk==1.39.2) (2.3.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.2) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.2) (3.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->bidirectional-cross-attention==0.0.4) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->bidirectional-cross-attention==0.0.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->bidirectional-cross-attention==0.0.4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->bidirectional-cross-attention==0.0.4) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->bidirectional-cross-attention==0.0.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.6->bidirectional-cross-attention==0.0.4) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6->bidirectional-cross-attention==0.0.4) (3.0.2)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading bidirectional_cross_attention-0.0.4-py3-none-any.whl (4.1 kB)
# Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.0 MB/s eta 0:00:00
# Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 23.5 MB/s eta 0:00:0000:01
# Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 10.5 MB/s eta 0:00:00
# Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Downloading jaxtyping-0.2.12-py3-none-any.whl (19 kB)
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 18.0 MB/s eta 0:00:00
# Downloading kornia-0.6.12-py2.py3-none-any.whl (653 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.4/653.4 kB 32.5 MB/s eta 0:00:00
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.3 MB/s eta 0:00:00
# Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 79.5 MB/s eta 0:00:00:00:010:01
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 24.1 MB/s eta 0:00:0000:0100:01m
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.7 MB/s eta 0:00:00
# Downloading plyfile-0.8.1-py3-none-any.whl (28 kB)
# Downloading prettytable-3.7.0-py3-none-any.whl (27 kB)
# Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 17.2 MB/s eta 0:00:00
# Downloading psutil-5.9.7-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.5/285.5 kB 15.9 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 5.8 MB/s eta 0:00:00
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 12.4 MB/s eta 0:00:00
# Downloading pytorch_fid-0.3.0-py3-none-any.whl (15 kB)
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 31.4 MB/s eta 0:00:00
# Downloading scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 50.6 MB/s eta 0:00:0000:0100:01m
# Downloading scipy-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 31.2 MB/s eta 0:00:0000:0100:01
# Downloading sentry_sdk-1.39.2-py2.py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 11.8 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.4 MB/s eta 0:00:00
# Downloading typeguard-4.1.2-py3-none-any.whl (33 kB)
# Downloading wandb-0.16.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 54.9 MB/s eta 0:00:00:00:01
# Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Downloading numpy-1.22.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 70.8 MB/s eta 0:00:00:00:0100:01
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... done
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.1-cp310-cp310-linux_x86_64.whl size=3656706 sha256=1a08efac39c6e21e2e315480772c398862473ed316fe40e8682bb4142d746259
#   Stored in directory: /root/.cache/pip/wheels/ef/67/58/6566a3b61c6ec0f2ca0c2c324cd035ef2955601f0fb3197d5f
# Successfully built torch-scatter
# Installing collected packages: appdirs, zipp, typeguard, tqdm, torch-scatter, threadpoolctl, six, setproctitle, sentry-sdk, pyyaml, pyparsing, psutil, protobuf, prettytable, packaging, numpy, joblib, fonttools, einops, cycler, scipy, python-dateutil, plyfile, opencv-python, jaxtyping, importlib-metadata, gitpython, wandb, scikit-learn, matplotlib, kornia, bidirectional-cross-attention, pytorch-fid, lpips
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Successfully uninstalled zipp-3.21.0
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setproctitle
#     Found existing installation: setproctitle 1.3.4
#     Uninstalling setproctitle-1.3.4:
#       Successfully uninstalled setproctitle-1.3.4
#   Attempting uninstall: sentry-sdk
#     Found existing installation: sentry-sdk 2.19.2
#     Uninstalling sentry-sdk-2.19.2:
#       Successfully uninstalled sentry-sdk-2.19.2
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.0
#     Uninstalling pyparsing-3.2.0:
#       Successfully uninstalled pyparsing-3.2.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.12.0
#     Uninstalling prettytable-3.12.0:
#       Successfully uninstalled prettytable-3.12.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.55.3
#     Uninstalling fonttools-4.55.3:
#       Successfully uninstalled fonttools-4.55.3
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: gitpython
#     Found existing installation: GitPython 3.1.43
#     Uninstalling GitPython-3.1.43:
#       Successfully uninstalled GitPython-3.1.43
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.19.1
#     Uninstalling wandb-0.19.1:
#       Successfully uninstalled wandb-0.19.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.5
#     Uninstalling matplotlib-3.7.5:
#       Successfully uninstalled matplotlib-3.7.5
#   Attempting uninstall: kornia
#     Found existing installation: kornia 0.8.0
#     Uninstalling kornia-0.8.0:
#       Successfully uninstalled kornia-0.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cartopy 0.24.1 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# cartopy 0.24.1 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.1 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.0.0 which is incompatible.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.22.4 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.22.4 which is incompatible.
# albumentations 1.4.20 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# arviz 0.20.0 requires numpy>=1.23.0, but you have numpy 1.22.4 which is incompatible.
# arviz 0.20.0 requires scipy>=1.9.0, but you have scipy 1.7.3 which is incompatible.
# astropy 6.1.7 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# bayesian-optimization 2.0.3 requires numpy>=1.25, but you have numpy 1.22.4 which is incompatible.
# bigframes 1.29.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.3 which is incompatible.
# bigframes 1.29.0 requires numpy>=1.24.0, but you have numpy 1.22.4 which is incompatible.
# bigframes 1.29.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.22.4 which is incompatible.
# contourpy 1.3.1 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# cudf-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# cuml-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# cuml-cu12 25.2.0 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# cuvs-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# dask-cuda 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# dask-cudf-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# datasets 3.3.1 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# dipy 1.10.0 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires numpy>=1.25.0, but you have numpy 1.22.4 which is incompatible.
# featuretools 1.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.24.4 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# ibis-framework 9.2.0 requires numpy<3,>=1.23.2, but you have numpy 1.22.4 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.22.4 which is incompatible.
# jax 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.22.4 which is incompatible.
# jaxlib 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# kaggle-environments 1.16.11 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# langchain 0.3.12 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# libpysal 4.9.2 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# mizani 0.13.1 requires numpy>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# mizani 0.13.1 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.22.4 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.22.4 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.22.4 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.0.2 which is incompatible.
# mne 1.9.0 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# mne 1.9.0 requires numpy<3,>=1.23, but you have numpy 1.22.4 which is incompatible.
# mne 1.9.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# nilearn 0.10.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# numexpr 2.10.2 requires numpy>=1.23.0, but you have numpy 1.22.4 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# pandas-stubs 2.2.2.240909 requires numpy>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.5.3 which is incompatible.
# plotnine 0.14.4 requires numpy>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# plotnine 0.14.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.22.4 which is incompatible.
# pylibraft-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# pymc 5.19.1 requires numpy>=1.25.0, but you have numpy 1.22.4 which is incompatible.
# pywavelets 1.8.0 requires numpy<3,>=1.23, but you have numpy 1.22.4 which is incompatible.
# rmm-cu12 25.2.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# scikit-image 0.25.0 requires numpy>=1.24, but you have numpy 1.22.4 which is incompatible.
# scikit-image 0.25.0 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# statsmodels 0.14.4 requires scipy!=1.9.2,>=1.8, but you have scipy 1.7.3 which is incompatible.
# stumpy 1.13.0 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# tensorflow 2.17.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 1.22.4 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# ucx-py-cu12 0.42.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# ucxx-cu12 0.42.0 requires numpy<3.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# visions 0.7.6 requires numpy>=1.23.2, but you have numpy 1.22.4 which is incompatible.
# woodwork 0.31.0 requires numpy>=1.25.0, but you have numpy 1.22.4 which is incompatible.
# woodwork 0.31.0 requires scikit-learn>=1.1.0, but you have scikit-learn 1.0.2 which is incompatible.
# woodwork 0.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# xarray 2024.11.0 requires numpy>=1.24, but you have numpy 1.22.4 which is incompatible.
# xarray-einstats 0.8.0 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# xarray-einstats 0.8.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# Successfully installed appdirs-1.4.4 bidirectional-cross-attention-0.0.4 cycler-0.11.0 einops-0.6.1 fonttools-4.38.0 gitpython-3.1.41 importlib-metadata-6.7.0 jaxtyping-0.2.12 joblib-1.3.2 kornia-0.6.12 lpips-0.1.4 matplotlib-3.5.3 numpy-1.22.4 opencv-python-4.9.0.80 packaging-23.2 plyfile-0.8.1 prettytable-3.7.0 protobuf-4.24.4 psutil-5.9.7 pyparsing-3.1.1 python-dateutil-2.8.2 pytorch-fid-0.3.0 pyyaml-6.0.1 scikit-learn-1.0.2 scipy-1.7.3 sentry-sdk-1.39.2 setproctitle-1.3.3 six-1.16.0 threadpoolctl-3.1.0 torch-scatter-2.1.1 tqdm-4.66.1 typeguard-4.1.2 wandb-0.16.2 zipp-3.15.0

# %%
# !pip install -e submodules/diff-gaussian-rasterization
# !pip install -e submodules/simple-knn
# Out:
# Obtaining file:///kaggle/working/GScream/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# Installing collected packages: diff_gaussian_rasterization
#   Running setup.py develop for diff_gaussian_rasterization
# Successfully installed diff_gaussian_rasterization-0.0.0
# Obtaining file:///kaggle/working/GScream/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# Installing collected packages: simple_knn
#   Running setup.py develop for simple_knn
# Successfully installed simple_knn-0.0.0

# %%
pip install numpy==1.23.0 --force-reinstall
# Out:
# Collecting numpy==1.23.0
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 78.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cartopy 0.24.1 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# albucore 0.0.19 requires numpy>=1.24.4, but you have numpy 1.23.0 which is incompatible.
# albumentations 1.4.20 requires numpy>=1.24.4, but you have numpy 1.23.0 which is incompatible.
# albumentations 1.4.20 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# arviz 0.20.0 requires scipy>=1.9.0, but you have scipy 1.7.3 which is incompatible.
# bayesian-optimization 2.0.3 requires numpy>=1.25, but you have numpy 1.23.0 which is incompatible.
# bigframes 1.29.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.3 which is incompatible.
# bigframes 1.29.0 requires numpy>=1.24.0, but you have numpy 1.23.0 which is incompatible.
# bigframes 1.29.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# chex 0.1.88 requires numpy>=1.24.1, but you have numpy 1.23.0 which is incompatible.
# cuml-cu12 25.2.0 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# datasets 3.3.1 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# dipy 1.10.0 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires numpy>=1.25.0, but you have numpy 1.23.0 which is incompatible.
# featuretools 1.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# ibis-framework 9.2.0 requires numpy<3,>=1.23.2, but you have numpy 1.23.0 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# jax 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# jaxlib 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# kaggle-environments 1.16.11 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# langchain 0.3.12 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# libpysal 4.9.2 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# mizani 0.13.1 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# mizani 0.13.1 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.23.0 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.23.0 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.23.0 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.0.2 which is incompatible.
# mne 1.9.0 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# mne 1.9.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# nilearn 0.10.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# pandas-stubs 2.2.2.240909 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.5.3 which is incompatible.
# plotnine 0.14.4 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# plotnine 0.14.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.23.0 which is incompatible.
# pymc 5.19.1 requires numpy>=1.25.0, but you have numpy 1.23.0 which is incompatible.
# scikit-image 0.25.0 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# scikit-image 0.25.0 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.0 which is incompatible.
# statsmodels 0.14.4 requires scipy!=1.9.2,>=1.8, but you have scipy 1.7.3 which is incompatible.
# stumpy 1.13.0 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# tensorflow 2.17.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 1.23.0 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# visions 0.7.6 requires numpy>=1.23.2, but you have numpy 1.23.0 which is incompatible.
# woodwork 0.31.0 requires numpy>=1.25.0, but you have numpy 1.23.0 which is incompatible.
# woodwork 0.31.0 requires scikit-learn>=1.1.0, but you have scikit-learn 1.0.2 which is incompatible.
# woodwork 0.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# xarray 2024.11.0 requires numpy>=1.24, but you have numpy 1.23.0 which is incompatible.
# xarray-einstats 0.8.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# Successfully installed numpy-1.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade numpy tensorflow tensorboard
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.0)
# Collecting numpy
#   Downloading numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Collecting tensorboard
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.24.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Collecting numpy
#   Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 MB 2.5 MB/s eta 0:00:000:00:010:01m
# Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 4.4 MB/s eta 0:00:000:00:0100:01
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 13.1 MB/s eta 0:00:00:00:0100:01
# Downloading ml_dtypes-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 69.9 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: numpy, tensorboard, ml-dtypes, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cartopy 0.24.1 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# albumentations 1.4.20 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# arviz 0.20.0 requires scipy>=1.9.0, but you have scipy 1.7.3 which is incompatible.
# bigframes 1.29.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.3 which is incompatible.
# bigframes 1.29.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# catboost 1.2.7 requires numpy<2.0,>=1.16.0, but you have numpy 2.1.3 which is incompatible.
# cuml-cu12 25.2.0 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.1.3 which is incompatible.
# datasets 3.3.1 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# dipy 1.10.0 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.1.3 which is incompatible.
# jax 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# jaxlib 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# kaggle-environments 1.16.11 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# langchain 0.3.12 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# langchain 0.3.12 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.1.3 which is incompatible.
# libpysal 4.9.2 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# mizani 0.13.1 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.1.3 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.1.3 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.1.3 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.0.2 which is incompatible.
# mne 1.9.0 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# mne 1.9.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# nilearn 0.10.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.3 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.5.3 which is incompatible.
# plotnine 0.14.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# pytensor 2.26.4 requires numpy<2,>=1.17.0, but you have numpy 2.1.3 which is incompatible.
# scikit-image 0.25.0 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.1.3 which is incompatible.
# statsmodels 0.14.4 requires scipy!=1.9.2,>=1.8, but you have scipy 1.7.3 which is incompatible.
# stumpy 1.13.0 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.19.0 which is incompatible.
# tensorflow-text 2.17.0 requires tensorflow<2.18,>=2.17.0, but you have tensorflow 2.19.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.19.0 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.3 which is incompatible.
# woodwork 0.31.0 requires scikit-learn>=1.1.0, but you have scikit-learn 1.0.2 which is incompatible.
# woodwork 0.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# xarray-einstats 0.8.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# Successfully installed ml-dtypes-0.5.1 numpy-2.1.3 tensorboard-2.19.0 tensorflow-2.19.0

# %%
pip install "numpy<2.0.0"
# Out:
# Collecting numpy<2.0.0
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 89.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cartopy 0.24.1 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# albumentations 1.4.20 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# arviz 0.20.0 requires scipy>=1.9.0, but you have scipy 1.7.3 which is incompatible.
# bigframes 1.29.0 requires matplotlib>=3.7.1, but you have matplotlib 3.5.3 which is incompatible.
# bigframes 1.29.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# cuml-cu12 25.2.0 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# datasets 3.3.1 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# dipy 1.10.0 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# jax 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# jaxlib 0.4.33 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# kaggle-environments 1.16.11 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# langchain 0.3.12 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# libpysal 4.9.2 requires scipy>=1.8, but you have scipy 1.7.3 which is incompatible.
# mizani 0.13.1 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.0.2 which is incompatible.
# mne 1.9.0 requires matplotlib>=3.6, but you have matplotlib 3.5.3 which is incompatible.
# mne 1.9.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# nilearn 0.10.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# plotnine 0.14.4 requires matplotlib>=3.8.0, but you have matplotlib 3.5.3 which is incompatible.
# plotnine 0.14.4 requires scipy>=1.8.0, but you have scipy 1.7.3 which is incompatible.
# scikit-image 0.25.0 requires scipy>=1.11.2, but you have scipy 1.7.3 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.26.4 which is incompatible.
# statsmodels 0.14.4 requires scipy!=1.9.2,>=1.8, but you have scipy 1.7.3 which is incompatible.
# stumpy 1.13.0 requires scipy>=1.10, but you have scipy 1.7.3 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.19.0 which is incompatible.
# tensorflow-text 2.17.0 requires tensorflow<2.18,>=2.17.0, but you have tensorflow 2.19.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.19.0 which is incompatible.
# woodwork 0.31.0 requires scikit-learn>=1.1.0, but you have scikit-learn 1.0.2 which is incompatible.
# woodwork 0.31.0 requires scipy>=1.10.0, but you have scipy 1.7.3 which is incompatible.
# xarray-einstats 0.8.0 requires scipy>=1.9, but you have scipy 1.7.3 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python scripts/run.py
# Out:
# ./refs/1_out.png
# ./refs/1_out_pred.npy
# /usr/local/lib/python3.10/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|█████████████████████████████████████████| 528M/528M [00:02<00:00, 205MB/s]
# /usr/local/lib/python3.10/dist-packages/lpips/lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# 2025-04-02 22:14:00.766180: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743632040.784208     443 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743632040.789328     443 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743632040.803669     443 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743632040.803693     443 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743632040.803696     443 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743632040.803700     443 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-02 22:14:08,182 - INFO: args: Namespace(sh_degree=3, feat_dim=32, n_offsets=10, voxel_size=0.005, update_depth=3, update_init_factor=16, update_hierachy_factor=4, use_feat_bank=False, source_path='/kaggle/input/spinnerf-dataset-processed/spinnerf_dataset_processed/1', model_path='outputs/spinnerf_dataset/1/gscream/', pretrained_model_path='', images='images', resolution=-1, white_background=False, data_device='cuda', eval=True, lod=0, specified_ply_path='/kaggle/input/spinnerf-dataset-processed/spinnerf_dataset_processed/1/sparse/0/points3D.ply', load_mask=True, load_depth=True, load_norm=True, load_midas=False, is_spin=True, is_ibr=False, ref_image_path='./refs/1_out.png', ref_depth_path='./refs/1_out_pred.npy', ref_normal_path='', ref_mask_path='', iterations=30000, position_lr_init=0.0, position_lr_final=0.0, position_lr_delay_mult=0.01, position_lr_max_steps=30000, offset_lr_init=0.01, offset_lr_final=0.0001, offset_lr_delay_mult=0.01, offset_lr_max_steps=30000, feature_lr=0.0075, opacity_lr=0.02, uncertainty_lr=0.0, scaling_lr=0.007, rotation_lr=0.002, mlp_opacity_lr_init=0.002, mlp_opacity_lr_final=2e-05, mlp_opacity_lr_delay_mult=0.01, mlp_opacity_lr_max_steps=30000, mlp_uncertainty_lr_init=0.002, mlp_uncertainty_lr_final=2e-05, mlp_uncertainty_lr_delay_mult=0.01, mlp_uncertainty_lr_max_steps=30000, mlp_cov_lr_init=0.004, mlp_cov_lr_final=0.004, mlp_cov_lr_delay_mult=0.01, mlp_cov_lr_max_steps=30000, mlp_color_lr_init=0.008, mlp_color_lr_final=5e-05, mlp_color_lr_delay_mult=0.01, mlp_color_lr_max_steps=30000, mlp_featurebank_lr_init=0.01, mlp_featurebank_lr_final=1e-05, mlp_featurebank_lr_delay_mult=0.01, mlp_featurebank_lr_max_steps=30000, discriminator_lr_init=0.01, discriminator_lr_final=1e-05, discriminator_lr_delay_mult=0.01, discriminator_lr_max_steps=30000, crossattn_lr_init=0.002, crossattn_lr_final=2e-05, crossattn_lr_delay_mult=0.01, crossattn_lr_max_steps=30000, selfattn_lr_init=0.01, selfattn_lr_final=1e-05, selfattn_lr_delay_mult=0.01, selfattn_lr_max_steps=30000, percent_dense=0.01, lambda_dssim=0.2, lambda_depth=1.0, start_stat=500, update_from=1500, update_interval=100, update_until=15000, start_crossattn_from=15000, min_opacity=0.005, success_threshold=0.8, densify_grad_threshold=0.0002, lpips_lr=0.0, lpips_b=20, perceptual_lr=0.0, perceptual_b=2, refer_rgb_lr=1.0, refer_rgb_lr_fg=20.0, other_rgb_lr=1.0, other_rgb_lr_fg=0.0, refer_depth_lr=1.0, refer_depth_lr_fg=100.0, refer_depth_lr_smooth=1.0, refer_depth_lr_smooth_edge=1.0, disp_smooth_lr=1.0, other_depth_lr=0.1, other_depth_lr_smooth=0.1, refer_normal_lr=0.0, other_normal_lr=0.0, refer_opacity_lr=0.0, other_opacity_lr=0.0, flat_lr=1.0, sparse_depth_lr=0.0, refer_warping_lr=0.0, vgg_lr=0.0, discriminator_lr=0.0, crossattn_lr=0.0, adv_lr=0.0, use_lama=False, pretrained_ply='', enable_crossattn_refview=1.0, enable_crossattn_otherview=1.0, attn_head_num=8, attn_head_dim=64, crossattn_feat_update_ema=0.03, enable_pe=0.0, enable_enlarge_samping=0.0, sampling_2D_enlarge_ratio=2.0, enable_edge_samping=1.0, enable_twopatch_samping=0.0, sampling_2D_small_ratio=0.6, enable_selfattn=0.0, selfattn_feat_update_ema=1.0, selfattn_knn_maxnum=2000, selfattn_sampling_rad=0.5, crossattn_start_iter=15000, perceptual_loss_weight=0.1, gradient_domain_loss_weight=0.5, boundary_emphasis=True, convert_SHs_python=False, compute_cov3D_python=False, debug=False, ip='127.0.0.1', port=10001, debug_from=-1, detect_anomaly=False, warmup=False, use_wandb=False, test_iterations=[30000], save_iterations=[30000, 30000], quiet=False, checkpoint_iterations=[], start_checkpoint=None, gpu='0')
# 2025-04-02 22:14:08,184 - INFO: using GPU 0
# 2025-04-02 22:14:08,185 - INFO: save code failed~
# 2025-04-02 22:14:08,185 - INFO: Optimizing outputs/spinnerf_dataset/1/gscream/
# Training progress:   0%|                              | 0/30000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Training progress: 100%|█| 30000/30000 [5:00:20<00:00,  1.66it/s, Loss=0.2140476
# 2025-04-03 03:15:33,271 - INFO:
# [ITER 30000] Evaluating test: L1 0.06834968971088529 PSNR 19.681440067291263
# 2025-04-03 03:15:39,386 - INFO:
# [ITER 30000] Evaluating train: L1 0.05072756558656693 PSNR 20.14935989379883
# 2025-04-03 03:15:39,465 - INFO:
# [ITER 30000] Saving Gaussians
# 2025-04-03 03:15:58,497 - INFO:
# Training complete.
# 2025-04-03 03:15:58,497 - INFO:
# Starting Rendering~
# /kaggle/working/GScream/scene/gaussian_model.py:994: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path)
# Rendering progress: 100%|█████████████████████| 120/120 [02:49<00:00,  1.42s/it]
# sh: 1: /usr/local/bin/ffmpeg: not found
# 2025-04-03 03:19:11,506 - INFO: Spiral FPS: 5.71579
# Rendering progress: 100%|███████████████████████| 60/60 [01:05<00:00,  1.09s/it]
# 2025-04-03 03:20:16,852 - INFO: Train FPS: 5.65872
# Rendering progress: 100%|███████████████████████| 40/40 [00:40<00:00,  1.02s/it]
# 2025-04-03 03:20:57,575 - INFO: Test FPS: 6.83694
# 2025-04-03 03:20:57,578 - INFO:
# Rendering complete.
# 2025-04-03 03:20:57,579 - INFO:
#  Starting evaluation...
# Metric evaluation progress: 100%|███████████████| 40/40 [00:15<00:00,  2.66it/s]
# 2025-04-03 03:21:15,187 - INFO: model_paths: outputs/spinnerf_dataset/1/gscream/
# 2025-04-03 03:21:15,188 - INFO:   SSIM :    0.4681066
# 2025-04-03 03:21:15,189 - INFO:   PSNR :   19.6809425
# 2025-04-03 03:21:15,190 - INFO:   LPIPS:    0.3238000
# 2025-04-03 03:21:15,190 - INFO:   masked SSIM :    0.1316250
# 2025-04-03 03:21:15,191 - INFO:   masked PSNR :   13.2172575
# 2025-04-03 03:21:15,192 - INFO:   masked LPIPS:    0.5729771
# 2025-04-03 03:21:15,198 - INFO:
# Evaluating complete.
# ./refs/9_out.png
# ./refs/9_out_pred.npy
# /usr/local/lib/python3.10/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.10/dist-packages/lpips/lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# 2025-04-03 03:21:26.783550: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743650486.803130     475 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743650486.808487     475 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743650486.825633     475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743650486.825656     475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743650486.825662     475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743650486.825668     475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-03 03:21:29,351 - INFO: args: Namespace(sh_degree=3, feat_dim=32, n_offsets=10, voxel_size=0.005, update_depth=3, update_init_factor=16, update_hierachy_factor=4, use_feat_bank=False, source_path='/kaggle/input/spinnerf-dataset-processed/spinnerf_dataset_processed/9', model_path='outputs/spinnerf_dataset/9/gscream/', pretrained_model_path='', images='images', resolution=-1, white_background=False, data_device='cuda', eval=True, lod=0, specified_ply_path='/kaggle/input/spinnerf-dataset-processed/spinnerf_dataset_processed/9/sparse/0/points3D.ply', load_mask=True, load_depth=True, load_norm=True, load_midas=False, is_spin=True, is_ibr=False, ref_image_path='./refs/9_out.png', ref_depth_path='./refs/9_out_pred.npy', ref_normal_path='', ref_mask_path='', iterations=30000, position_lr_init=0.0, position_lr_final=0.0, position_lr_delay_mult=0.01, position_lr_max_steps=30000, offset_lr_init=0.01, offset_lr_final=0.0001, offset_lr_delay_mult=0.01, offset_lr_max_steps=30000, feature_lr=0.0075, opacity_lr=0.02, uncertainty_lr=0.0, scaling_lr=0.007, rotation_lr=0.002, mlp_opacity_lr_init=0.002, mlp_opacity_lr_final=2e-05, mlp_opacity_lr_delay_mult=0.01, mlp_opacity_lr_max_steps=30000, mlp_uncertainty_lr_init=0.002, mlp_uncertainty_lr_final=2e-05, mlp_uncertainty_lr_delay_mult=0.01, mlp_uncertainty_lr_max_steps=30000, mlp_cov_lr_init=0.004, mlp_cov_lr_final=0.004, mlp_cov_lr_delay_mult=0.01, mlp_cov_lr_max_steps=30000, mlp_color_lr_init=0.008, mlp_color_lr_final=5e-05, mlp_color_lr_delay_mult=0.01, mlp_color_lr_max_steps=30000, mlp_featurebank_lr_init=0.01, mlp_featurebank_lr_final=1e-05, mlp_featurebank_lr_delay_mult=0.01, mlp_featurebank_lr_max_steps=30000, discriminator_lr_init=0.01, discriminator_lr_final=1e-05, discriminator_lr_delay_mult=0.01, discriminator_lr_max_steps=30000, crossattn_lr_init=0.002, crossattn_lr_final=2e-05, crossattn_lr_delay_mult=0.01, crossattn_lr_max_steps=30000, selfattn_lr_init=0.01, selfattn_lr_final=1e-05, selfattn_lr_delay_mult=0.01, selfattn_lr_max_steps=30000, percent_dense=0.01, lambda_dssim=0.2, lambda_depth=1.0, start_stat=500, update_from=1500, update_interval=100, update_until=15000, start_crossattn_from=15000, min_opacity=0.005, success_threshold=0.8, densify_grad_threshold=0.0002, lpips_lr=0.0, lpips_b=20, perceptual_lr=0.0, perceptual_b=2, refer_rgb_lr=1.0, refer_rgb_lr_fg=20.0, other_rgb_lr=1.0, other_rgb_lr_fg=0.0, refer_depth_lr=1.0, refer_depth_lr_fg=100.0, refer_depth_lr_smooth=1.0, refer_depth_lr_smooth_edge=1.0, disp_smooth_lr=1.0, other_depth_lr=0.1, other_depth_lr_smooth=0.1, refer_normal_lr=0.0, other_normal_lr=0.0, refer_opacity_lr=0.0, other_opacity_lr=0.0, flat_lr=1.0, sparse_depth_lr=0.0, refer_warping_lr=0.0, vgg_lr=0.0, discriminator_lr=0.0, crossattn_lr=0.0, adv_lr=0.0, use_lama=False, pretrained_ply='', enable_crossattn_refview=1.0, enable_crossattn_otherview=1.0, attn_head_num=8, attn_head_dim=64, crossattn_feat_update_ema=0.03, enable_pe=0.0, enable_enlarge_samping=0.0, sampling_2D_enlarge_ratio=2.0, enable_edge_samping=1.0, enable_twopatch_samping=0.0, sampling_2D_small_ratio=0.6, enable_selfattn=0.0, selfattn_feat_update_ema=1.0, selfattn_knn_maxnum=2000, selfattn_sampling_rad=0.5, crossattn_start_iter=15000, perceptual_loss_weight=0.1, gradient_domain_loss_weight=0.5, boundary_emphasis=True, convert_SHs_python=False, compute_cov3D_python=False, debug=False, ip='127.0.0.1', port=10001, debug_from=-1, detect_anomaly=False, warmup=False, use_wandb=False, test_iterations=[30000], save_iterations=[30000, 30000], quiet=False, checkpoint_iterations=[], start_checkpoint=None, gpu='0')
# 2025-04-03 03:21:29,353 - INFO: using GPU 0
# 2025-04-03 03:21:29,353 - INFO: save code failed~
# 2025-04-03 03:21:29,353 - INFO: Optimizing outputs/spinnerf_dataset/9/gscream/
# Training progress:   0%|                              | 0/30000 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Training progress:  58%|▌| 17490/30000 [3:03:19<2:02:04,  1.71it/s, Loss=0.15803

# %%
# import shutil

# # Path to the folder you want to zip
# folder_to_zip = "/kaggle/working/GScream/outputs"

# # Define the output zip file path
# zip_file_path = "/kaggle/working/outputs_new.zip"

# # Create a zip archive of the folder
# shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', folder_to_zip)

# # Now you can download the zip file using the link provided below.

# %%
# from IPython.display import FileLink

# # Provide the path to the zip file for download
# FileLink("/kaggle/working/outputs.zip")
